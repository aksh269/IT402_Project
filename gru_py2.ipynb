# %%
# ============================================================
# 1. IMPORTS
# ============================================================
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
# ============================================================
# 2. DEVICE + REPRODUCIBILITY
# ============================================================
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using Device: {device}")

np.random.seed(42)
torch.manual_seed(42)
# Out:
# Using Device: cuda

# %%
# ============================================================
# 3. HYPERPARAMETERS
# ============================================================
LOOKBACK_GRID = [30, 60,90,120,150]
HIDDEN_SIZE = 128
NUM_LAYERS = 2
DROPOUT = 0.1
LR = 1e-3
EPOCHS = 500
TARGET_COVERAGE = 0.95
LAMBDA_WIDTH = 0.05

# Quantiles used by the model
q_low = 0.025
q_high = 0.975

# %%
# ============================================================
# 4. DATA LOADING + FEATURE ENGINEERING
# ============================================================
def load_and_prep_data(filepath="KO.csv"):
    df = pd.read_csv(filepath)
    df.columns = df.columns.str.strip()

    df["Date"] = pd.to_datetime(df["Date"]).dt.tz_localize(None)
    df = df.sort_values("Date").reset_index(drop=True)

    # Feature Engineering
    df["log_return"] = np.log(df["Close"]).diff()
    df["volatility"] = df["log_return"].rolling(5).std()
    df["hl_range"] = (df["High"] - df["Low"]) / df["Close"]

    # Sentiment active impact
    df["sentiment_signed"] = 2 * (df["Scaled_sentiment"] - 0.5)
    df["sentiment_active"] = df["sentiment_signed"] * df["News_flag"]
    df["sentiment_impact"] = df["sentiment_active"] * df["log_return"].shift(1)

    df["target"] = df["Close"].shift(-1)
    df = df.replace([np.inf, -np.inf], np.nan).dropna()

    return df

# %%
# ============================================================
# 5. SEQUENCE GENERATOR
# ============================================================
def create_seq(X, y, dates, L):
    Xs, ys, ds = [], [], []
    for i in range(L, len(X)):
        Xs.append(X[i - L:i])
        ys.append(y[i])
        ds.append(dates.iloc[i])
    return np.array(Xs), np.array(ys), np.array(ds)

# %%
# ============================================================
# 6. LSTM MODEL + QUANTILE LOSS
# ============================================================
class GRUModel(nn.Module):
    def __init__(self, input_size):
        super().__init__()
        self.gru = nn.GRU(
            input_size,
            HIDDEN_SIZE,
            NUM_LAYERS,
            batch_first=True,
            dropout=DROPOUT if NUM_LAYERS > 1 else 0
        )
        self.fc = nn.Linear(HIDDEN_SIZE, 1)

    def forward(self, x):
        out, _ = self.gru(x)
        out = out[:, -1, :]
        return self.fc(out).squeeze()

def qloss(pred, y, q):
    """Quantile (Pinball) Loss for training."""
    e = y - pred
    return torch.mean(torch.maximum((q - 1) * e, q * e))

# %%
# ============================================================
# 7. TRAIN + PREDICT FUNCTION
# ============================================================
def train_and_predict(df, features, lookback, model_name="Model"):
    print(f"\n--- Training {model_name} (Lookback: {lookback}) ---")
    split = int(len(df) * 0.8)

    train_df = df.iloc[:split]

    scalerX = StandardScaler()
    scalerY = StandardScaler()

    scalerX.fit(train_df[features])
    scalerY.fit(train_df[["target"]])

    X = scalerX.transform(df[features])
    y = scalerY.transform(df[["target"]]).ravel()

    X_seq, y_seq, dates = create_seq(X, y, df["Date"], lookback)
    split_date = df["Date"].iloc[split]

    train_mask = dates < split_date
    test_mask = dates >= split_date

    X_train = torch.tensor(X_seq[train_mask], dtype=torch.float32).to(device)
    y_train = torch.tensor(y_seq[train_mask], dtype=torch.float32).to(device)

    X_test = torch.tensor(X_seq[test_mask], dtype=torch.float32).to(device)
    y_test = y_seq[test_mask]
    dates_test = dates[test_mask]

    def train_q(q, q_label):
        model = GRUModel(X_train.shape[2]).to(device)
        opt = torch.optim.Adam(model.parameters(), lr=LR)

        for epoch in range(EPOCHS):
            pred = model(X_train)
            loss = qloss(pred, y_train, q)

            opt.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            opt.step()

            if (epoch + 1) % 40 == 0 or epoch == 0:
                print(f"[{q_label}] Epoch {epoch+1:03d}/{EPOCHS} | Loss: {loss.item():.4f}")

        return model

    model_low = train_q(q_low, "Low Quantile ")
    model_high = train_q(q_high, "High Quantile")

    with torch.no_grad():
        low = model_low(X_test).cpu().numpy()
        high = model_high(X_test).cpu().numpy()

    # Inverse scaling to actual prices
    low = scalerY.inverse_transform(low.reshape(-1, 1)).ravel()
    high = scalerY.inverse_transform(high.reshape(-1, 1)).ravel()
    y_true = scalerY.inverse_transform(y_test.reshape(-1, 1)).ravel()

    return low, high, y_true, dates_test

# %%
# ============================================================
# 8. CALIBRATION FUNCTION
# ============================================================
def calibrate(y, low, high):
    """Calibrate bounds to hit target coverage smoothly."""
    best_scale = 1
    best_score = 1e9

    for s in np.linspace(0.5, 2.0, 40):
        mid = (low + high) / 2
        l = mid - s * (mid - low)
        h = mid + s * (high - mid)

        cov = np.mean((y >= l) & (y <= h))
        width = np.mean(h - l)

        score = abs(cov - TARGET_COVERAGE) + LAMBDA_WIDTH * width

        if score < best_score:
            best_score = score
            best_scale = s

    mid = (low + high) / 2
    cal_low = mid - best_scale * (mid - low)
    cal_high = mid + best_scale * (high - mid)

    return cal_low, cal_high

# %%
# ============================================================
# 9. METRIC HELPERS
# ============================================================
def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

def pinball_loss_np(y_true, y_pred, q):
    y_true = np.asarray(y_true).ravel()
    y_pred = np.asarray(y_pred).ravel()
    return np.mean(np.maximum(q * (y_true - y_pred), (q - 1) * (y_true - y_pred)))

# %%
# ============================================================
# 10. DATA + FEATURE SETS
# ============================================================
df = load_and_prep_data("KO.csv")

base_features = ["Close", "log_return", "volatility", "hl_range"]
sent_features = base_features + ["sentiment_active", "sentiment_impact"]

results = []
forecast_data = {}

# %%
# ============================================================
# 11. TRAINING LOOP
# ============================================================
for L in LOOKBACK_GRID:
    low1, high1, y_true, dates = train_and_predict(df, base_features, L, "Base GRU Model")
    low2, high2, _, _ = train_and_predict(df, sent_features, L, "Sentiment GRU Model")

    low1, high1 = calibrate(y_true, low1, high1)
    low2, high2 = calibrate(y_true, low2, high2)

    mid1, mid2 = (low1 + high1) / 2, (low2 + high2) / 2

    # Coverage and width
    cov1 = np.mean((y_true >= low1) & (y_true <= high1))
    cov2 = np.mean((y_true >= low2) & (y_true <= high2))

    width1 = np.mean(high1 - low1)
    width2 = np.mean(high2 - low2)

    # Point-forecast metrics using midpoint of interval
    mae1 = mean_absolute_error(y_true, mid1)
    mse1 = mean_squared_error(y_true, mid1)
    rmse1 = rmse(y_true, mid1)

    mae2 = mean_absolute_error(y_true, mid2)
    mse2 = mean_squared_error(y_true, mid2)
    rmse2 = rmse(y_true, mid2)

    # Pinball loss for both quantiles
    pbl_low1 = pinball_loss_np(y_true, low1, q_low)
    pbl_high1 = pinball_loss_np(y_true, high1, q_high)

    pbl_low2 = pinball_loss_np(y_true, low2, q_low)
    pbl_high2 = pinball_loss_np(y_true, high2, q_high)

    results.append((
        L,
        cov1, width1, mae1, mse1, rmse1, pbl_low1, pbl_high1,
        cov2, width2, mae2, mse2, rmse2, pbl_low2, pbl_high2
    ))

    forecast_data[L] = {
        "dates": dates,
        "actual": y_true,
        "base_low": low1, "base_high": high1, "base_mid": mid1,
        "sent_low": low2, "sent_high": high2, "sent_mid": mid2
    }
# Out:
# --- Training Base GRU Model (Lookback: 30) ---
# [Low Quantile ] Epoch 001/500 | Loss: 0.3555
# [Low Quantile ] Epoch 040/500 | Loss: 0.0088
# [Low Quantile ] Epoch 080/500 | Loss: 0.0064
# [Low Quantile ] Epoch 120/500 | Loss: 0.0062
# [Low Quantile ] Epoch 160/500 | Loss: 0.0061
# [Low Quantile ] Epoch 200/500 | Loss: 0.0059
# [Low Quantile ] Epoch 240/500 | Loss: 0.0058
# [Low Quantile ] Epoch 280/500 | Loss: 0.0058
# [Low Quantile ] Epoch 320/500 | Loss: 0.0058
# [Low Quantile ] Epoch 360/500 | Loss: 0.0058
# [Low Quantile ] Epoch 400/500 | Loss: 0.0055
# [Low Quantile ] Epoch 440/500 | Loss: 0.0055
# [Low Quantile ] Epoch 480/500 | Loss: 0.0054
# [High Quantile] Epoch 001/500 | Loss: 0.3303
# [High Quantile] Epoch 040/500 | Loss: 0.0089
# [High Quantile] Epoch 080/500 | Loss: 0.0056
# [High Quantile] Epoch 120/500 | Loss: 0.0053
# [High Quantile] Epoch 160/500 | Loss: 0.0051
# [High Quantile] Epoch 200/500 | Loss: 0.0049
# [High Quantile] Epoch 240/500 | Loss: 0.0050
# [High Quantile] Epoch 280/500 | Loss: 0.0048
# [High Quantile] Epoch 320/500 | Loss: 0.0047
# [High Quantile] Epoch 360/500 | Loss: 0.0048
# [High Quantile] Epoch 400/500 | Loss: 0.0047
# [High Quantile] Epoch 440/500 | Loss: 0.0045
# [High Quantile] Epoch 480/500 | Loss: 0.0047
#
# --- Training Sentiment GRU Model (Lookback: 30) ---
# [Low Quantile ] Epoch 001/500 | Loss: 0.3568
# [Low Quantile ] Epoch 040/500 | Loss: 0.0092
# [Low Quantile ] Epoch 080/500 | Loss: 0.0064
# [Low Quantile ] Epoch 120/500 | Loss: 0.0063
# [Low Quantile ] Epoch 160/500 | Loss: 0.0060
# [Low Quantile ] Epoch 200/500 | Loss: 0.0059
# [Low Quantile ] Epoch 240/500 | Loss: 0.0056
# [Low Quantile ] Epoch 280/500 | Loss: 0.0055
# [Low Quantile ] Epoch 320/500 | Loss: 0.0054
# [Low Quantile ] Epoch 360/500 | Loss: 0.0052
# [Low Quantile ] Epoch 400/500 | Loss: 0.0051
# [Low Quantile ] Epoch 440/500 | Loss: 0.0050
# [Low Quantile ] Epoch 480/500 | Loss: 0.0049
# [High Quantile] Epoch 001/500 | Loss: 0.3828
# [High Quantile] Epoch 040/500 | Loss: 0.0098
# [High Quantile] Epoch 080/500 | Loss: 0.0056
# [High Quantile] Epoch 120/500 | Loss: 0.0051
# [High Quantile] Epoch 160/500 | Loss: 0.0050
# [High Quantile] Epoch 200/500 | Loss: 0.0048
# [High Quantile] Epoch 240/500 | Loss: 0.0045
# [High Quantile] Epoch 280/500 | Loss: 0.0044
# [High Quantile] Epoch 320/500 | Loss: 0.0043
# [High Quantile] Epoch 360/500 | Loss: 0.0043
# [High Quantile] Epoch 400/500 | Loss: 0.0042
# [High Quantile] Epoch 440/500 | Loss: 0.0042
# [High Quantile] Epoch 480/500 | Loss: 0.0040
#
# --- Training Base GRU Model (Lookback: 60) ---
# [Low Quantile ] Epoch 001/500 | Loss: 0.3828
# [Low Quantile ] Epoch 040/500 | Loss: 0.0093
# [Low Quantile ] Epoch 080/500 | Loss: 0.0066
# [Low Quantile ] Epoch 120/500 | Loss: 0.0062
# [Low Quantile ] Epoch 160/500 | Loss: 0.0061
# [Low Quantile ] Epoch 200/500 | Loss: 0.0060
# [Low Quantile ] Epoch 240/500 | Loss: 0.0059
# [Low Quantile ] Epoch 280/500 | Loss: 0.0060
# [Low Quantile ] Epoch 320/500 | Loss: 0.0058
# [Low Quantile ] Epoch 360/500 | Loss: 0.0057
# [Low Quantile ] Epoch 400/500 | Loss: 0.0056
# [Low Quantile ] Epoch 440/500 | Loss: 0.0055
# [Low Quantile ] Epoch 480/500 | Loss: 0.0055
# [High Quantile] Epoch 001/500 | Loss: 0.3699
# [High Quantile] Epoch 040/500 | Loss: 0.0079
# [High Quantile] Epoch 080/500 | Loss: 0.0056
# [High Quantile] Epoch 120/500 | Loss: 0.0052
# [High Quantile] Epoch 160/500 | Loss: 0.0053
# [High Quantile] Epoch 200/500 | Loss: 0.0050
# [High Quantile] Epoch 240/500 | Loss: 0.0049
# [High Quantile] Epoch 280/500 | Loss: 0.0048
# [High Quantile] Epoch 320/500 | Loss: 0.0047
# [High Quantile] Epoch 360/500 | Loss: 0.0047
# [High Quantile] Epoch 400/500 | Loss: 0.0047
# [High Quantile] Epoch 440/500 | Loss: 0.0047
# [High Quantile] Epoch 480/500 | Loss: 0.0044
#
# --- Training Sentiment GRU Model (Lookback: 60) ---
# [Low Quantile ] Epoch 001/500 | Loss: 0.3449
# [Low Quantile ] Epoch 040/500 | Loss: 0.0085
# [Low Quantile ] Epoch 080/500 | Loss: 0.0064
# [Low Quantile ] Epoch 120/500 | Loss: 0.0061
# [Low Quantile ] Epoch 160/500 | Loss: 0.0060
# [Low Quantile ] Epoch 200/500 | Loss: 0.0059
# [Low Quantile ] Epoch 240/500 | Loss: 0.0057
# [Low Quantile ] Epoch 280/500 | Loss: 0.0055
# [Low Quantile ] Epoch 320/500 | Loss: 0.0054
# [Low Quantile ] Epoch 360/500 | Loss: 0.0053
# [Low Quantile ] Epoch 400/500 | Loss: 0.0052
# [Low Quantile ] Epoch 440/500 | Loss: 0.0050
# [Low Quantile ] Epoch 480/500 | Loss: 0.0049
# [High Quantile] Epoch 001/500 | Loss: 0.4191
# [High Quantile] Epoch 040/500 | Loss: 0.0081
# [High Quantile] Epoch 080/500 | Loss: 0.0054
# [High Quantile] Epoch 120/500 | Loss: 0.0052
# [High Quantile] Epoch 160/500 | Loss: 0.0050
# [High Quantile] Epoch 200/500 | Loss: 0.0047
# [High Quantile] Epoch 240/500 | Loss: 0.0046
# [High Quantile] Epoch 280/500 | Loss: 0.0045
# [High Quantile] Epoch 320/500 | Loss: 0.0044
# [High Quantile] Epoch 360/500 | Loss: 0.0043
# [High Quantile] Epoch 400/500 | Loss: 0.0043
# [High Quantile] Epoch 440/500 | Loss: 0.0043
# [High Quantile] Epoch 480/500 | Loss: 0.0042
#
# --- Training Base GRU Model (Lookback: 90) ---
# [Low Quantile ] Epoch 001/500 | Loss: 0.3646
# [Low Quantile ] Epoch 040/500 | Loss: 0.0086
# [Low Quantile ] Epoch 080/500 | Loss: 0.0065
# [Low Quantile ] Epoch 120/500 | Loss: 0.0062
# [Low Quantile ] Epoch 160/500 | Loss: 0.0062
# [Low Quantile ] Epoch 200/500 | Loss: 0.0061
# [Low Quantile ] Epoch 240/500 | Loss: 0.0059
# [Low Quantile ] Epoch 280/500 | Loss: 0.0060
# [Low Quantile ] Epoch 320/500 | Loss: 0.0058
# [Low Quantile ] Epoch 360/500 | Loss: 0.0058
# [Low Quantile ] Epoch 400/500 | Loss: 0.0057
# [Low Quantile ] Epoch 440/500 | Loss: 0.0057
# [Low Quantile ] Epoch 480/500 | Loss: 0.0054
# [High Quantile] Epoch 001/500 | Loss: 0.3828
# [High Quantile] Epoch 040/500 | Loss: 0.0084
# [High Quantile] Epoch 080/500 | Loss: 0.0056
# [High Quantile] Epoch 120/500 | Loss: 0.0052
# [High Quantile] Epoch 160/500 | Loss: 0.0051
# [High Quantile] Epoch 200/500 | Loss: 0.0050
# [High Quantile] Epoch 240/500 | Loss: 0.0049
# [High Quantile] Epoch 280/500 | Loss: 0.0049
# [High Quantile] Epoch 320/500 | Loss: 0.0048
# [High Quantile] Epoch 360/500 | Loss: 0.0048
# [High Quantile] Epoch 400/500 | Loss: 0.0047
# [High Quantile] Epoch 440/500 | Loss: 0.0046
# [High Quantile] Epoch 480/500 | Loss: 0.0045
#
# --- Training Sentiment GRU Model (Lookback: 90) ---
# [Low Quantile ] Epoch 001/500 | Loss: 0.3117
# [Low Quantile ] Epoch 040/500 | Loss: 0.0090
# [Low Quantile ] Epoch 080/500 | Loss: 0.0063
# [Low Quantile ] Epoch 120/500 | Loss: 0.0061
# [Low Quantile ] Epoch 160/500 | Loss: 0.0060
# [Low Quantile ] Epoch 200/500 | Loss: 0.0059
# [Low Quantile ] Epoch 240/500 | Loss: 0.0057
# [Low Quantile ] Epoch 280/500 | Loss: 0.0055
# [Low Quantile ] Epoch 320/500 | Loss: 0.0054
# [Low Quantile ] Epoch 360/500 | Loss: 0.0053
# [Low Quantile ] Epoch 400/500 | Loss: 0.0052
# [Low Quantile ] Epoch 440/500 | Loss: 0.0050
# [Low Quantile ] Epoch 480/500 | Loss: 0.0051
# [High Quantile] Epoch 001/500 | Loss: 0.3796
# [High Quantile] Epoch 040/500 | Loss: 0.0084
# [High Quantile] Epoch 080/500 | Loss: 0.0055
# [High Quantile] Epoch 120/500 | Loss: 0.0051
# [High Quantile] Epoch 160/500 | Loss: 0.0049
# [High Quantile] Epoch 200/500 | Loss: 0.0048
# [High Quantile] Epoch 240/500 | Loss: 0.0046
# [High Quantile] Epoch 280/500 | Loss: 0.0045
# [High Quantile] Epoch 320/500 | Loss: 0.0044
# [High Quantile] Epoch 360/500 | Loss: 0.0043
# [High Quantile] Epoch 400/500 | Loss: 0.0043
# [High Quantile] Epoch 440/500 | Loss: 0.0042
# [High Quantile] Epoch 480/500 | Loss: 0.0041
#
# --- Training Base GRU Model (Lookback: 120) ---
# [Low Quantile ] Epoch 001/500 | Loss: 0.3083
# [Low Quantile ] Epoch 040/500 | Loss: 0.0084
# [Low Quantile ] Epoch 080/500 | Loss: 0.0066
# [Low Quantile ] Epoch 120/500 | Loss: 0.0063
# [Low Quantile ] Epoch 160/500 | Loss: 0.0062
# [Low Quantile ] Epoch 200/500 | Loss: 0.0062
# [Low Quantile ] Epoch 240/500 | Loss: 0.0060
# [Low Quantile ] Epoch 280/500 | Loss: 0.0058
# [Low Quantile ] Epoch 320/500 | Loss: 0.0058
# [Low Quantile ] Epoch 360/500 | Loss: 0.0057
# [Low Quantile ] Epoch 400/500 | Loss: 0.0055
# [Low Quantile ] Epoch 440/500 | Loss: 0.0056
# [Low Quantile ] Epoch 480/500 | Loss: 0.0055
# [High Quantile] Epoch 001/500 | Loss: 0.3096
# [High Quantile] Epoch 040/500 | Loss: 0.0077
# [High Quantile] Epoch 080/500 | Loss: 0.0054
# [High Quantile] Epoch 120/500 | Loss: 0.0054
# [High Quantile] Epoch 160/500 | Loss: 0.0052
# [High Quantile] Epoch 200/500 | Loss: 0.0051
# [High Quantile] Epoch 240/500 | Loss: 0.0050
# [High Quantile] Epoch 280/500 | Loss: 0.0048
# [High Quantile] Epoch 320/500 | Loss: 0.0048
# [High Quantile] Epoch 360/500 | Loss: 0.0048
# [High Quantile] Epoch 400/500 | Loss: 0.0047
# [High Quantile] Epoch 440/500 | Loss: 0.0046
# [High Quantile] Epoch 480/500 | Loss: 0.0047
#
# --- Training Sentiment GRU Model (Lookback: 120) ---
# [Low Quantile ] Epoch 001/500 | Loss: 0.3569
# [Low Quantile ] Epoch 040/500 | Loss: 0.0089
# [Low Quantile ] Epoch 080/500 | Loss: 0.0063
# [Low Quantile ] Epoch 120/500 | Loss: 0.0062
# [Low Quantile ] Epoch 160/500 | Loss: 0.0060
# [Low Quantile ] Epoch 200/500 | Loss: 0.0058
# [Low Quantile ] Epoch 240/500 | Loss: 0.0056
# [Low Quantile ] Epoch 280/500 | Loss: 0.0055
# [Low Quantile ] Epoch 320/500 | Loss: 0.0054
# [Low Quantile ] Epoch 360/500 | Loss: 0.0052
# [Low Quantile ] Epoch 400/500 | Loss: 0.0051
# [Low Quantile ] Epoch 440/500 | Loss: 0.0049
# [Low Quantile ] Epoch 480/500 | Loss: 0.0049
# [High Quantile] Epoch 001/500 | Loss: 0.4124
# [High Quantile] Epoch 040/500 | Loss: 0.0089
# [High Quantile] Epoch 080/500 | Loss: 0.0056
# [High Quantile] Epoch 120/500 | Loss: 0.0052
# [High Quantile] Epoch 160/500 | Loss: 0.0048
# [High Quantile] Epoch 200/500 | Loss: 0.0047
# [High Quantile] Epoch 240/500 | Loss: 0.0046
# [High Quantile] Epoch 280/500 | Loss: 0.0047
# [High Quantile] Epoch 320/500 | Loss: 0.0044
# [High Quantile] Epoch 360/500 | Loss: 0.0044
# [High Quantile] Epoch 400/500 | Loss: 0.0043
# [High Quantile] Epoch 440/500 | Loss: 0.0042
# [High Quantile] Epoch 480/500 | Loss: 0.0043
#
# --- Training Base GRU Model (Lookback: 150) ---
# [Low Quantile ] Epoch 001/500 | Loss: 0.3310
# [Low Quantile ] Epoch 040/500 | Loss: 0.0085
# [Low Quantile ] Epoch 080/500 | Loss: 0.0065
# [Low Quantile ] Epoch 120/500 | Loss: 0.0063
# [Low Quantile ] Epoch 160/500 | Loss: 0.0060
# [Low Quantile ] Epoch 200/500 | Loss: 0.0061
# [Low Quantile ] Epoch 240/500 | Loss: 0.0059
# [Low Quantile ] Epoch 280/500 | Loss: 0.0058
# [Low Quantile ] Epoch 320/500 | Loss: 0.0059
# [Low Quantile ] Epoch 360/500 | Loss: 0.0057
# [Low Quantile ] Epoch 400/500 | Loss: 0.0056
# [Low Quantile ] Epoch 440/500 | Loss: 0.0055
# [Low Quantile ] Epoch 480/500 | Loss: 0.0053
# [High Quantile] Epoch 001/500 | Loss: 0.4011
# [High Quantile] Epoch 040/500 | Loss: 0.0090
# [High Quantile] Epoch 080/500 | Loss: 0.0055
# [High Quantile] Epoch 120/500 | Loss: 0.0053
# [High Quantile] Epoch 160/500 | Loss: 0.0052
# [High Quantile] Epoch 200/500 | Loss: 0.0050
# [High Quantile] Epoch 240/500 | Loss: 0.0049
# [High Quantile] Epoch 280/500 | Loss: 0.0050
# [High Quantile] Epoch 320/500 | Loss: 0.0048
# [High Quantile] Epoch 360/500 | Loss: 0.0047
# [High Quantile] Epoch 400/500 | Loss: 0.0047
# [High Quantile] Epoch 440/500 | Loss: 0.0045
# [High Quantile] Epoch 480/500 | Loss: 0.0046
#
# --- Training Sentiment GRU Model (Lookback: 150) ---
# [Low Quantile ] Epoch 001/500 | Loss: 0.2953
# [Low Quantile ] Epoch 040/500 | Loss: 0.0081
# [Low Quantile ] Epoch 080/500 | Loss: 0.0064
# [Low Quantile ] Epoch 120/500 | Loss: 0.0062
# [Low Quantile ] Epoch 160/500 | Loss: 0.0059
# [Low Quantile ] Epoch 200/500 | Loss: 0.0058
# [Low Quantile ] Epoch 240/500 | Loss: 0.0056
# [Low Quantile ] Epoch 280/500 | Loss: 0.0055
# [Low Quantile ] Epoch 320/500 | Loss: 0.0054
# [Low Quantile ] Epoch 360/500 | Loss: 0.0051
# [Low Quantile ] Epoch 400/500 | Loss: 0.0050
# [Low Quantile ] Epoch 440/500 | Loss: 0.0049
# [Low Quantile ] Epoch 480/500 | Loss: 0.0047
# [High Quantile] Epoch 001/500 | Loss: 0.4110
# [High Quantile] Epoch 040/500 | Loss: 0.0095
# [High Quantile] Epoch 080/500 | Loss: 0.0057
# [High Quantile] Epoch 120/500 | Loss: 0.0051
# [High Quantile] Epoch 160/500 | Loss: 0.0050
# [High Quantile] Epoch 200/500 | Loss: 0.0048
# [High Quantile] Epoch 240/500 | Loss: 0.0047
# [High Quantile] Epoch 280/500 | Loss: 0.0046
# [High Quantile] Epoch 320/500 | Loss: 0.0044
# [High Quantile] Epoch 360/500 | Loss: 0.0043
# [High Quantile] Epoch 400/500 | Loss: 0.0044
# [High Quantile] Epoch 440/500 | Loss: 0.0041
# [High Quantile] Epoch 480/500 | Loss: 0.0041

# %%
# ============================================================
# 12. COMPARISON PRINTOUT
# ============================================================
print("\n" + "=" * 132)
print(f"{'FINAL COMPARISON (Base vs Sentiment - GRU)':^132}")
print("=" * 132)
print(
    f"{'Lookback':<9} | "
    f"{'Base Cov':<8} | {'Base Wdth':<9} | {'Base MAE':<9} | {'Base MSE':<9} | {'Base RMSE':<9} | {'Base PB-L':<10} | {'Base PB-H':<10} || "
    f"{'Sent Cov':<8} | {'Sent Wdth':<9} | {'Sent MAE':<9} | {'Sent MSE':<9} | {'Sent RMSE':<9} | {'Sent PB-L':<10} | {'Sent PB-H':<10}"
)
print("-" * 132)

for r in results:
    print(
        f"{r[0]:<9} | "
        f"{r[1]:<8.4f} | {r[2]:<9.4f} | {r[3]:<9.4f} | {r[4]:<9.4f} | {r[5]:<9.4f} | {r[6]:<10.4f} | {r[7]:<10.4f} || "
        f"{r[8]:<8.4f} | {r[9]:<9.4f} | {r[10]:<9.4f} | {r[11]:<9.4f} | {r[12]:<9.4f} | {r[13]:<10.4f} | {r[14]:<10.4f}"
    )

# Optional summary averages across lookbacks
base_avg = np.mean(np.array([[r[1], r[2], r[3], r[4], r[5], r[6], r[7]] for r in results]), axis=0)
sent_avg = np.mean(np.array([[r[8], r[9], r[10], r[11], r[12], r[13], r[14]] for r in results]), axis=0)

print("\n" + "=" * 90)
print(f"{'AVERAGE ACROSS LOOKBACKS':^90}")
print("=" * 90)
print(f"Base      -> Coverage: {base_avg[0]:.4f}, Width: {base_avg[1]:.4f}, MAE: {base_avg[2]:.4f}, MSE: {base_avg[3]:.4f}, RMSE: {base_avg[4]:.4f}, Pinball-L: {base_avg[5]:.4f}, Pinball-H: {base_avg[6]:.4f}")
print(f"Sentiment -> Coverage: {sent_avg[0]:.4f}, Width: {sent_avg[1]:.4f}, MAE: {sent_avg[2]:.4f}, MSE: {sent_avg[3]:.4f}, RMSE: {sent_avg[4]:.4f}, Pinball-L: {sent_avg[5]:.4f}, Pinball-H: {sent_avg[6]:.4f}")
# Out:
# ====================================================================================================================================
#                                              FINAL COMPARISON (Base vs Sentiment - GRU)
# ====================================================================================================================================
# Lookback  | Base Cov | Base Wdth | Base MAE  | Base MSE  | Base RMSE | Base PB-L  | Base PB-H  || Sent Cov | Sent Wdth | Sent MAE  | Sent MSE  | Sent RMSE | Sent PB-L  | Sent PB-H
# ------------------------------------------------------------------------------------------------------------------------------------
# 30        | 0.9299   | 5.4124    | 1.3223    | 2.7551    | 1.6599    | 0.0965     | 0.0773     || 0.9243   | 5.6851    | 1.1883    | 2.3555    | 1.5348    | 0.0997     | 0.1043
# 60        | 0.9481   | 5.4903    | 1.2871    | 2.6508    | 1.6281    | 0.0955     | 0.0665     || 0.9439   | 5.7223    | 1.2113    | 2.4003    | 1.5493    | 0.1010     | 0.0836
# 90        | 0.9467   | 5.7121    | 1.3230    | 2.7662    | 1.6632    | 0.0994     | 0.0713     || 0.9369   | 5.6594    | 1.2028    | 2.3180    | 1.5225    | 0.1000     | 0.0858
# 120       | 0.9369   | 5.2283    | 1.2209    | 2.4291    | 1.5586    | 0.0902     | 0.0730     || 0.9173   | 5.1329    | 1.1628    | 2.1899    | 1.4798    | 0.0913     | 0.0868
# 150       | 0.9327   | 5.8721    | 1.4733    | 3.3528    | 1.8311    | 0.1064     | 0.0794     || 0.9313   | 6.3243    | 1.5720    | 3.6729    | 1.9165    | 0.1146     | 0.0873
#
# ==========================================================================================
#                                  AVERAGE ACROSS LOOKBACKS
# ==========================================================================================
# Base      -> Coverage: 0.9388, Width: 5.5430, MAE: 1.3253, MSE: 2.7908, RMSE: 1.6682, Pinball-L: 0.0976, Pinball-H: 0.0735
# Sentiment -> Coverage: 0.9307, Width: 5.7048, MAE: 1.2674, MSE: 2.5873, RMSE: 1.6006, Pinball-L: 0.1013, Pinball-H: 0.0896

# %%
# ============================================================
# 13. PLOTS
# ============================================================

# Plot 1: Coverage vs Lookback
plt.figure(figsize=(10, 5))
plt.plot([r[0] for r in results], [r[1] for r in results], marker='o', label="Base (No Sent)")
plt.plot([r[0] for r in results], [r[8] for r in results], marker='o', label="With Sentiment")
plt.axhline(TARGET_COVERAGE, color='black', linestyle='--', label="Target Coverage")
plt.xlabel("Sequence Length (Lookback)")
plt.ylabel("Coverage")
plt.title("GRU: Coverage vs. Sequence Length")
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
# Plot 2: Width vs Lookback
plt.figure(figsize=(10, 5))
plt.plot([r[0] for r in results], [r[2] for r in results], marker='o', label="Base (No Sent)")
plt.plot([r[0] for r in results], [r[9] for r in results], marker='o', label="With Sentiment")
plt.xlabel("Sequence Length (Lookback)")
plt.ylabel("Average Interval Width")
plt.title("GRU: Uncertainty Width vs. Sequence Length")
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
# Plot 3 and 4: Forecast visualizations for each model and each lookback
for L in LOOKBACK_GRID:
    data = forecast_data[L]

    plt.figure(figsize=(12, 5))
    plt.plot(data["dates"], data["actual"], label="Actual Price", color='black', linewidth=1.5)
    plt.plot(data["dates"], data["base_mid"], label="Base Midpoint", color='blue', alpha=0.8)
    plt.fill_between(data["dates"], data["base_low"], data["base_high"], color='blue', alpha=0.2, label="95% Interval")
    plt.title(f"Base GRU Model Prediction (Lookback: {L})")
    plt.xlabel("Date")
    plt.ylabel("Price")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.gcf().autofmt_xdate()
    plt.show()

    plt.figure(figsize=(12, 5))
    plt.plot(data["dates"], data["actual"], label="Actual Price", color='black', linewidth=1.5)
    plt.plot(data["dates"], data["sent_mid"], label="Sent. Midpoint", color='green', alpha=0.8)
    plt.fill_between(data["dates"], data["sent_low"], data["sent_high"], color='green', alpha=0.2, label="95% Interval")
    plt.title(f"Sentiment GRU Model Prediction (Lookback: {L})")
    plt.xlabel("Date")
    plt.ylabel("Price")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.gcf().autofmt_xdate()
    plt.show()

# %%
# ============================================================
# 14. ERROR METRICS COMPARISON PLOTS
# ============================================================

lookbacks = [r[0] for r in results]

# Extract metrics
base_mae = [r[3] for r in results]
base_mse = [r[4] for r in results]
base_rmse = [r[5] for r in results]
base_pbl = [r[6] for r in results]
base_pbh = [r[7] for r in results]

sent_mae = [r[10] for r in results]
sent_mse = [r[11] for r in results]
sent_rmse = [r[12] for r in results]
sent_pbl = [r[13] for r in results]
sent_pbh = [r[14] for r in results]

# %%
# -----------------------------
# MAE Plot
# -----------------------------
plt.figure()
plt.plot(lookbacks, base_mae, marker='o', label="Base MAE")
plt.plot(lookbacks, sent_mae, marker='o', label="Sentiment MAE")
plt.title("GRU---MAE Comparison")
plt.xlabel("Lookback")
plt.ylabel("MAE")
plt.legend()
plt.grid()
plt.show()

# %%
# -----------------------------
# MSE Plot
# -----------------------------
plt.figure()
plt.plot(lookbacks, base_mse, marker='o', label="Base MSE")
plt.plot(lookbacks, sent_mse, marker='o', label="Sentiment MSE")
plt.title("GRU---MSE Comparison")
plt.xlabel("Lookback")
plt.ylabel("MSE")
plt.legend()
plt.grid()
plt.show()

# %%
# -----------------------------
# RMSE Plot
# -----------------------------
plt.figure()
plt.plot(lookbacks, base_rmse, marker='o', label="Base RMSE")
plt.plot(lookbacks, sent_rmse, marker='o', label="Sentiment RMSE")
plt.title("GRU---RMSE Comparison")
plt.xlabel("Lookback")
plt.ylabel("RMSE")
plt.legend()
plt.grid()
plt.show()

# %%
# -----------------------------
# Pinball Loss (Lower Quantile)
# -----------------------------
plt.figure()
plt.plot(lookbacks, base_pbl, marker='o', label="Base Pinball Low")
plt.plot(lookbacks, sent_pbl, marker='o', label="Sentiment Pinball Low")
plt.title(f"GRU---Pinball Loss Comparison (q={q_low})")
plt.xlabel("Lookback")
plt.ylabel("Pinball Loss")
plt.legend()
plt.grid()
plt.show()

# %%
# -----------------------------
# Pinball Loss (Upper Quantile)
# -----------------------------
plt.figure()
plt.plot(lookbacks, base_pbh, marker='o', label="Base Pinball High")
plt.plot(lookbacks, sent_pbh, marker='o', label="Sentiment Pinball High")
plt.title(f"GRU---Pinball Loss Comparison (q={q_high})")
plt.xlabel("Lookback")
plt.ylabel("Pinball Loss")
plt.legend()
plt.grid()
plt.show()
