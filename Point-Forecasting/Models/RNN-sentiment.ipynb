# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
# LOAD DATA
df = pd.read_csv("../../Final_data/KO.csv")
df["Date"] = pd.to_datetime(df["Date"])
df = df.sort_values("Date").reset_index(drop=True)

# FEATURE ENGINEERING
df["ret1"] = df["Close"].pct_change()
df["ma5"] = df["Close"].rolling(5).mean()
df["ma10"] = df["Close"].rolling(10).mean()
df["std5"] = df["Close"].rolling(5).std()
df["lag1"] = df["Close"].shift(1)

df["Sentiment_gpt"] = df["Sentiment_gpt"].shift(1)

df["News_flag"] = df["News_flag"].shift(1)

df = df.dropna().reset_index(drop=True)

# FEATURES
features = ["Close", "ret1","Volume", "ma5", "ma10", "std5", "lag1", "Sentiment_gpt", "News_flag"]
data = df[features].values

# SPLIT (70 / 15 / 15)
n = len(data)
train_end = int(n * 0.7)
val_end = int(n * 0.85)

train_data = data[:train_end]
val_data   = data[train_end:val_end]
test_data  = data[val_end:]

# SCALE (NO LEAKAGE)
scaler = MinMaxScaler()

train_scaled = scaler.fit_transform(train_data)
val_scaled   = scaler.transform(val_data)
test_scaled  = scaler.transform(test_data)

# SEQUENCES
def create_sequences(data, seq_len):
    X, y = [], []
    for i in range(seq_len, len(data)):
        X.append(data[i-seq_len:i])
        y.append(data[i][0])  # Close
    return np.array(X), np.array(y)

SEQ_LEN = 10

X_train, y_train = create_sequences(train_scaled, SEQ_LEN)
X_val, y_val     = create_sequences(val_scaled, SEQ_LEN)
X_test, y_test   = create_sequences(test_scaled, SEQ_LEN)

# TENSORS
X_train = torch.tensor(X_train, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32).view(-1,1)

X_val = torch.tensor(X_val, dtype=torch.float32)
y_val = torch.tensor(y_val, dtype=torch.float32).view(-1,1)

X_test = torch.tensor(X_test, dtype=torch.float32)

# ADD NOISE
X_train = X_train + 0.01 * torch.randn_like(X_train)

# MODEL
class SimpleRNN(nn.Module):
    def __init__(self, input_size):
        super().__init__()
        self.rnn = nn.RNN(input_size=input_size, hidden_size=96, batch_first=True)
        self.fc = nn.Sequential(
            nn.Linear(96, 32),
            nn.ReLU(),
            nn.Linear(32, 1)
        )

    def forward(self, x):
        out, _ = self.rnn(x)
        out = out[:, -1, :]
        return self.fc(out)

model = SimpleRNN(input_size=len(features))

# TRAINING
criterion = nn.HuberLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.0005)

EPOCHS = 200
best_val_loss = float("inf")

for epoch in range(EPOCHS):

    model.train()
    pred = model(X_train)
    loss = criterion(pred, y_train)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    # validation
    model.eval()
    with torch.no_grad():
        val_pred = model(X_val)
        val_loss = criterion(val_pred, y_val).item()

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model_state = model.state_dict()

    if epoch % 10 == 0:
        print(f"Epoch {epoch} | Train Loss: {loss.item():.5f} | Val Loss: {val_loss:.5f}")

# LOAD BEST MODEL
model.load_state_dict(best_model_state)

# TEST PREDICTION
model.eval()
with torch.no_grad():
    preds = model(X_test).numpy()

# INVERSE SCALING (CORRECT WAY)
dummy = np.zeros((len(preds), len(features)))
dummy[:, 0] = preds.flatten()
preds = scaler.inverse_transform(dummy)[:, 0].reshape(-1,1)

dummy_actual = np.zeros((len(y_test), len(features)))
dummy_actual[:, 0] = y_test.flatten()
actual = scaler.inverse_transform(dummy_actual)[:, 0].reshape(-1,1)

# BIAS CORRECTION (KEY STEP)
bias = np.mean(actual - preds)
preds = preds + bias

# METRIC
rmse = np.sqrt(mean_squared_error(actual, preds))

r2 = r2_score(actual, preds)

direction_acc = np.mean(
    np.sign(np.diff(actual.flatten())) == 
    np.sign(np.diff(preds.flatten()))
)

print("\nRMSE:", round(rmse,4))
print("R2 Score:", round(r2,4))
print("Direction Accuracy:", round(direction_acc,4))

# PLOT
dates = df["Date"].iloc[-len(actual):]

plt.figure(figsize=(12,5))

plt.plot(dates, actual, label="Actual")
plt.plot(dates, preds, label="Predicted")

plt.title("RNN-sentiment (Actual vs Predicted)")
plt.xlabel("Date")
plt.ylabel("Price")

plt.legend()
plt.grid(True)
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()
# Out:
# Epoch 0 | Train Loss: 0.15189 | Val Loss: 0.39127
# Epoch 10 | Train Loss: 0.04996 | Val Loss: 0.16641
# Epoch 20 | Train Loss: 0.01724 | Val Loss: 0.01452
# Epoch 30 | Train Loss: 0.00855 | Val Loss: 0.05298
# Epoch 40 | Train Loss: 0.00609 | Val Loss: 0.03016
# Epoch 50 | Train Loss: 0.00441 | Val Loss: 0.02324
# Epoch 60 | Train Loss: 0.00246 | Val Loss: 0.01680
# Epoch 70 | Train Loss: 0.00126 | Val Loss: 0.01114
# Epoch 80 | Train Loss: 0.00112 | Val Loss: 0.00736
# Epoch 90 | Train Loss: 0.00084 | Val Loss: 0.00715
# Epoch 100 | Train Loss: 0.00071 | Val Loss: 0.00639
# Epoch 110 | Train Loss: 0.00057 | Val Loss: 0.00502
# Epoch 120 | Train Loss: 0.00047 | Val Loss: 0.00396
# Epoch 130 | Train Loss: 0.00039 | Val Loss: 0.00331
# Epoch 140 | Train Loss: 0.00034 | Val Loss: 0.00271
# Epoch 150 | Train Loss: 0.00031 | Val Loss: 0.00220
# Epoch 160 | Train Loss: 0.00029 | Val Loss: 0.00191
# Epoch 170 | Train Loss: 0.00027 | Val Loss: 0.00169
# Epoch 180 | Train Loss: 0.00025 | Val Loss: 0.00154
# Epoch 190 | Train Loss: 0.00024 | Val Loss: 0.00143
#
# RMSE: 1.3958
# R2 Score: 0.7618
# Direction Accuracy: 0.5048
