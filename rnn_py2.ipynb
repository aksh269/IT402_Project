# %%
# ============================================================
# 1. IMPORTS
# ============================================================
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
# ============================================================
# 2. DEVICE + REPRODUCIBILITY
# ============================================================
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using Device: {device}")

np.random.seed(42)
torch.manual_seed(42)
# Out:
# Using Device: cuda

# %%
# ============================================================
# 3. HYPERPARAMETERS
# ============================================================
LOOKBACK_GRID = [30, 60, 90,120,150]
HIDDEN_SIZE = 128
NUM_LAYERS = 2
DROPOUT = 0.1
LR = 1e-3
EPOCHS = 500
TARGET_COVERAGE = 0.95
LAMBDA_WIDTH = 0.05

# Quantiles used by the model
q_low = 0.025
q_high = 0.975

# %%
# ============================================================
# 4. DATA LOADING + FEATURE ENGINEERING
# ============================================================
def load_and_prep_data(filepath="KO.csv"):
    df = pd.read_csv(filepath)
    df.columns = df.columns.str.strip()

    df["Date"] = pd.to_datetime(df["Date"]).dt.tz_localize(None)
    df = df.sort_values("Date").reset_index(drop=True)

    # Feature Engineering
    df["log_return"] = np.log(df["Close"]).diff()
    df["volatility"] = df["log_return"].rolling(5).std()
    df["hl_range"] = (df["High"] - df["Low"]) / df["Close"]

    # Sentiment active impact
    df["sentiment_signed"] = 2 * (df["Scaled_sentiment"] - 0.5)
    df["sentiment_active"] = df["sentiment_signed"] * df["News_flag"]
    df["sentiment_impact"] = df["sentiment_active"] * df["log_return"].shift(1)

    df["target"] = df["Close"].shift(-1)
    df = df.replace([np.inf, -np.inf], np.nan).dropna()

    return df

# %%
# ============================================================
# 5. SEQUENCE GENERATOR
# ============================================================
def create_seq(X, y, dates, L):
    Xs, ys, ds = [], [], []
    for i in range(L, len(X)):
        Xs.append(X[i - L:i])
        ys.append(y[i])
        ds.append(dates.iloc[i])
    return np.array(Xs), np.array(ys), np.array(ds)

# %%
# ============================================================
# 6. LSTM MODEL + QUANTILE LOSS
# ============================================================
class RNNModel(nn.Module):
    def __init__(self, input_size):
        super().__init__()
        self.rnn = nn.RNN(
            input_size,
            HIDDEN_SIZE,
            NUM_LAYERS,
            batch_first=True,
            nonlinearity='tanh',
            dropout=DROPOUT if NUM_LAYERS > 1 else 0
        )
        self.fc = nn.Linear(HIDDEN_SIZE, 1)

    def forward(self, x):
        out, _ = self.rnn(x)
        out = out[:, -1, :]
        return self.fc(out).squeeze()

def qloss(pred, y, q):
    """Quantile (Pinball) Loss for training."""
    e = y - pred
    return torch.mean(torch.maximum((q - 1) * e, q * e))

# %%
# ============================================================
# 7. TRAIN + PREDICT FUNCTION
# ============================================================
def train_and_predict(df, features, lookback, model_name="Model"):
    print(f"\n--- Training {model_name} (Lookback: {lookback}) ---")
    split = int(len(df) * 0.8)

    train_df = df.iloc[:split]

    scalerX = StandardScaler()
    scalerY = StandardScaler()

    scalerX.fit(train_df[features])
    scalerY.fit(train_df[["target"]])

    X = scalerX.transform(df[features])
    y = scalerY.transform(df[["target"]]).ravel()

    X_seq, y_seq, dates = create_seq(X, y, df["Date"], lookback)
    split_date = df["Date"].iloc[split]

    train_mask = dates < split_date
    test_mask = dates >= split_date

    X_train = torch.tensor(X_seq[train_mask], dtype=torch.float32).to(device)
    y_train = torch.tensor(y_seq[train_mask], dtype=torch.float32).to(device)

    X_test = torch.tensor(X_seq[test_mask], dtype=torch.float32).to(device)
    y_test = y_seq[test_mask]
    dates_test = dates[test_mask]

    def train_q(q, q_label):
        model = RNNModel(X_train.shape[2]).to(device)
        opt = torch.optim.Adam(model.parameters(), lr=LR)

        for epoch in range(EPOCHS):
            pred = model(X_train)
            loss = qloss(pred, y_train, q)

            opt.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            opt.step()

            if (epoch + 1) % 40 == 0 or epoch == 0:
                print(f"[{q_label}] Epoch {epoch+1:03d}/{EPOCHS} | Loss: {loss.item():.4f}")

        return model

    model_low = train_q(q_low, "Low Quantile ")
    model_high = train_q(q_high, "High Quantile")

    with torch.no_grad():
        low = model_low(X_test).cpu().numpy()
        high = model_high(X_test).cpu().numpy()

    # Inverse scaling to actual prices
    low = scalerY.inverse_transform(low.reshape(-1, 1)).ravel()
    high = scalerY.inverse_transform(high.reshape(-1, 1)).ravel()
    y_true = scalerY.inverse_transform(y_test.reshape(-1, 1)).ravel()

    return low, high, y_true, dates_test

# %%
# ============================================================
# 8. CALIBRATION FUNCTION
# ============================================================
def calibrate(y, low, high):
    """Calibrate bounds to hit target coverage smoothly."""
    best_scale = 1
    best_score = 1e9

    for s in np.linspace(0.5, 2.0, 40):
        mid = (low + high) / 2
        l = mid - s * (mid - low)
        h = mid + s * (high - mid)

        cov = np.mean((y >= l) & (y <= h))
        width = np.mean(h - l)

        score = abs(cov - TARGET_COVERAGE) + LAMBDA_WIDTH * width

        if score < best_score:
            best_score = score
            best_scale = s

    mid = (low + high) / 2
    cal_low = mid - best_scale * (mid - low)
    cal_high = mid + best_scale * (high - mid)

    return cal_low, cal_high

# %%
# ============================================================
# 9. METRIC HELPERS
# ============================================================
def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

def pinball_loss_np(y_true, y_pred, q):
    y_true = np.asarray(y_true).ravel()
    y_pred = np.asarray(y_pred).ravel()
    return np.mean(np.maximum(q * (y_true - y_pred), (q - 1) * (y_true - y_pred)))

# %%
# ============================================================
# 10. DATA + FEATURE SETS
# ============================================================
df = load_and_prep_data("KO.csv")

base_features = ["Close", "log_return", "volatility", "hl_range"]
sent_features = base_features + ["sentiment_active", "sentiment_impact"]

results = []
forecast_data = {}

# %%
# ============================================================
# 11. TRAINING LOOP
# ============================================================
for L in LOOKBACK_GRID:
    low1, high1, y_true, dates = train_and_predict(df, base_features, L, "Base LSTM Model")
    low2, high2, _, _ = train_and_predict(df, sent_features, L, "Sentiment LSTM Model")

    low1, high1 = calibrate(y_true, low1, high1)
    low2, high2 = calibrate(y_true, low2, high2)

    mid1, mid2 = (low1 + high1) / 2, (low2 + high2) / 2

    # Coverage and width
    cov1 = np.mean((y_true >= low1) & (y_true <= high1))
    cov2 = np.mean((y_true >= low2) & (y_true <= high2))

    width1 = np.mean(high1 - low1)
    width2 = np.mean(high2 - low2)

    # Point-forecast metrics using midpoint of interval
    mae1 = mean_absolute_error(y_true, mid1)
    mse1 = mean_squared_error(y_true, mid1)
    rmse1 = rmse(y_true, mid1)

    mae2 = mean_absolute_error(y_true, mid2)
    mse2 = mean_squared_error(y_true, mid2)
    rmse2 = rmse(y_true, mid2)

    # Pinball loss for both quantiles
    pbl_low1 = pinball_loss_np(y_true, low1, q_low)
    pbl_high1 = pinball_loss_np(y_true, high1, q_high)

    pbl_low2 = pinball_loss_np(y_true, low2, q_low)
    pbl_high2 = pinball_loss_np(y_true, high2, q_high)

    results.append((
        L,
        cov1, width1, mae1, mse1, rmse1, pbl_low1, pbl_high1,
        cov2, width2, mae2, mse2, rmse2, pbl_low2, pbl_high2
    ))

    forecast_data[L] = {
        "dates": dates,
        "actual": y_true,
        "base_low": low1, "base_high": high1, "base_mid": mid1,
        "sent_low": low2, "sent_high": high2, "sent_mid": mid2
    }
# Out:
# --- Training Base LSTM Model (Lookback: 30) ---
# [Low Quantile ] Epoch 001/500 | Loss: 0.3091
# [Low Quantile ] Epoch 040/500 | Loss: 0.0088
# [Low Quantile ] Epoch 080/500 | Loss: 0.0068
# [Low Quantile ] Epoch 120/500 | Loss: 0.0066
# [Low Quantile ] Epoch 160/500 | Loss: 0.0063
# [Low Quantile ] Epoch 200/500 | Loss: 0.0062
# [Low Quantile ] Epoch 240/500 | Loss: 0.0061
# [Low Quantile ] Epoch 280/500 | Loss: 0.0061
# [Low Quantile ] Epoch 320/500 | Loss: 0.0060
# [Low Quantile ] Epoch 360/500 | Loss: 0.0059
# [Low Quantile ] Epoch 400/500 | Loss: 0.0058
# [Low Quantile ] Epoch 440/500 | Loss: 0.0057
# [Low Quantile ] Epoch 480/500 | Loss: 0.0054
# [High Quantile] Epoch 001/500 | Loss: 0.3199
# [High Quantile] Epoch 040/500 | Loss: 0.0076
# [High Quantile] Epoch 080/500 | Loss: 0.0058
# [High Quantile] Epoch 120/500 | Loss: 0.0056
# [High Quantile] Epoch 160/500 | Loss: 0.0054
# [High Quantile] Epoch 200/500 | Loss: 0.0052
# [High Quantile] Epoch 240/500 | Loss: 0.0053
# [High Quantile] Epoch 280/500 | Loss: 0.0053
# [High Quantile] Epoch 320/500 | Loss: 0.0052
# [High Quantile] Epoch 360/500 | Loss: 0.0050
# [High Quantile] Epoch 400/500 | Loss: 0.0059
# [High Quantile] Epoch 440/500 | Loss: 0.0059
# [High Quantile] Epoch 480/500 | Loss: 0.0050
#
# --- Training Sentiment LSTM Model (Lookback: 30) ---
# [Low Quantile ] Epoch 001/500 | Loss: 0.4143
# [Low Quantile ] Epoch 040/500 | Loss: 0.0093
# [Low Quantile ] Epoch 080/500 | Loss: 0.0069
# [Low Quantile ] Epoch 120/500 | Loss: 0.0067
# [Low Quantile ] Epoch 160/500 | Loss: 0.0064
# [Low Quantile ] Epoch 200/500 | Loss: 0.0061
# [Low Quantile ] Epoch 240/500 | Loss: 0.0062
# [Low Quantile ] Epoch 280/500 | Loss: 0.0063
# [Low Quantile ] Epoch 320/500 | Loss: 0.0059
# [Low Quantile ] Epoch 360/500 | Loss: 0.0059
# [Low Quantile ] Epoch 400/500 | Loss: 0.0064
# [Low Quantile ] Epoch 440/500 | Loss: 0.0059
# [Low Quantile ] Epoch 480/500 | Loss: 0.0058
# [High Quantile] Epoch 001/500 | Loss: 0.3629
# [High Quantile] Epoch 040/500 | Loss: 0.0094
# [High Quantile] Epoch 080/500 | Loss: 0.0059
# [High Quantile] Epoch 120/500 | Loss: 0.0057
# [High Quantile] Epoch 160/500 | Loss: 0.0053
# [High Quantile] Epoch 200/500 | Loss: 0.0057
# [High Quantile] Epoch 240/500 | Loss: 0.0049
# [High Quantile] Epoch 280/500 | Loss: 0.0048
# [High Quantile] Epoch 320/500 | Loss: 0.0116
# [High Quantile] Epoch 360/500 | Loss: 0.0107
# [High Quantile] Epoch 400/500 | Loss: 0.0050
# [High Quantile] Epoch 440/500 | Loss: 0.0051
# [High Quantile] Epoch 480/500 | Loss: 0.0050
#
# --- Training Base LSTM Model (Lookback: 60) ---
# [Low Quantile ] Epoch 001/500 | Loss: 0.3400
# [Low Quantile ] Epoch 040/500 | Loss: 0.0079
# [Low Quantile ] Epoch 080/500 | Loss: 0.0067
# [Low Quantile ] Epoch 120/500 | Loss: 0.0064
# [Low Quantile ] Epoch 160/500 | Loss: 0.0064
# [Low Quantile ] Epoch 200/500 | Loss: 0.0065
# [Low Quantile ] Epoch 240/500 | Loss: 0.0063
# [Low Quantile ] Epoch 280/500 | Loss: 0.0062
# [Low Quantile ] Epoch 320/500 | Loss: 0.0059
# [Low Quantile ] Epoch 360/500 | Loss: 0.0066
# [Low Quantile ] Epoch 400/500 | Loss: 0.0063
# [Low Quantile ] Epoch 440/500 | Loss: 0.0061
# [Low Quantile ] Epoch 480/500 | Loss: 0.0059
# [High Quantile] Epoch 001/500 | Loss: 0.3911
# [High Quantile] Epoch 040/500 | Loss: 0.0087
# [High Quantile] Epoch 080/500 | Loss: 0.0060
# [High Quantile] Epoch 120/500 | Loss: 0.0055
# [High Quantile] Epoch 160/500 | Loss: 0.0055
# [High Quantile] Epoch 200/500 | Loss: 0.0053
# [High Quantile] Epoch 240/500 | Loss: 0.0053
# [High Quantile] Epoch 280/500 | Loss: 0.0053
# [High Quantile] Epoch 320/500 | Loss: 0.0050
# [High Quantile] Epoch 360/500 | Loss: 0.0051
# [High Quantile] Epoch 400/500 | Loss: 0.0051
# [High Quantile] Epoch 440/500 | Loss: 0.0050
# [High Quantile] Epoch 480/500 | Loss: 0.0049
#
# --- Training Sentiment LSTM Model (Lookback: 60) ---
# [Low Quantile ] Epoch 001/500 | Loss: 0.3959
# [Low Quantile ] Epoch 040/500 | Loss: 0.0095
# [Low Quantile ] Epoch 080/500 | Loss: 0.0069
# [Low Quantile ] Epoch 120/500 | Loss: 0.0065
# [Low Quantile ] Epoch 160/500 | Loss: 0.0064
# [Low Quantile ] Epoch 200/500 | Loss: 0.0064
# [Low Quantile ] Epoch 240/500 | Loss: 0.0062
# [Low Quantile ] Epoch 280/500 | Loss: 0.0061
# [Low Quantile ] Epoch 320/500 | Loss: 0.0064
# [Low Quantile ] Epoch 360/500 | Loss: 0.0058
# [Low Quantile ] Epoch 400/500 | Loss: 0.0058
# [Low Quantile ] Epoch 440/500 | Loss: 0.0058
# [Low Quantile ] Epoch 480/500 | Loss: 0.0062
# [High Quantile] Epoch 001/500 | Loss: 0.3465
# [High Quantile] Epoch 040/500 | Loss: 0.0084
# [High Quantile] Epoch 080/500 | Loss: 0.0062
# [High Quantile] Epoch 120/500 | Loss: 0.0057
# [High Quantile] Epoch 160/500 | Loss: 0.0053
# [High Quantile] Epoch 200/500 | Loss: 0.0052
# [High Quantile] Epoch 240/500 | Loss: 0.0051
# [High Quantile] Epoch 280/500 | Loss: 0.0051
# [High Quantile] Epoch 320/500 | Loss: 0.0096
# [High Quantile] Epoch 360/500 | Loss: 0.0051
# [High Quantile] Epoch 400/500 | Loss: 0.0048
# [High Quantile] Epoch 440/500 | Loss: 0.0051
# [High Quantile] Epoch 480/500 | Loss: 0.0048
#
# --- Training Base LSTM Model (Lookback: 90) ---
# [Low Quantile ] Epoch 001/500 | Loss: 0.2874
# [Low Quantile ] Epoch 040/500 | Loss: 0.0087
# [Low Quantile ] Epoch 080/500 | Loss: 0.0068
# [Low Quantile ] Epoch 120/500 | Loss: 0.0066
# [Low Quantile ] Epoch 160/500 | Loss: 0.0064
# [Low Quantile ] Epoch 200/500 | Loss: 0.0064
# [Low Quantile ] Epoch 240/500 | Loss: 0.0061
# [Low Quantile ] Epoch 280/500 | Loss: 0.0060
# [Low Quantile ] Epoch 320/500 | Loss: 0.0060
# [Low Quantile ] Epoch 360/500 | Loss: 0.0057
# [Low Quantile ] Epoch 400/500 | Loss: 0.0070
# [Low Quantile ] Epoch 440/500 | Loss: 0.0060
# [Low Quantile ] Epoch 480/500 | Loss: 0.0058
# [High Quantile] Epoch 001/500 | Loss: 0.4385
# [High Quantile] Epoch 040/500 | Loss: 0.0086
# [High Quantile] Epoch 080/500 | Loss: 0.0062
# [High Quantile] Epoch 120/500 | Loss: 0.0057
# [High Quantile] Epoch 160/500 | Loss: 0.0053
# [High Quantile] Epoch 200/500 | Loss: 0.0051
# [High Quantile] Epoch 240/500 | Loss: 0.0052
# [High Quantile] Epoch 280/500 | Loss: 0.0051
# [High Quantile] Epoch 320/500 | Loss: 0.0059
# [High Quantile] Epoch 360/500 | Loss: 0.0050
# [High Quantile] Epoch 400/500 | Loss: 0.0050
# [High Quantile] Epoch 440/500 | Loss: 0.0048
# [High Quantile] Epoch 480/500 | Loss: 0.0050
#
# --- Training Sentiment LSTM Model (Lookback: 90) ---
# [Low Quantile ] Epoch 001/500 | Loss: 0.3190
# [Low Quantile ] Epoch 040/500 | Loss: 0.0086
# [Low Quantile ] Epoch 080/500 | Loss: 0.0068
# [Low Quantile ] Epoch 120/500 | Loss: 0.0066
# [Low Quantile ] Epoch 160/500 | Loss: 0.0066
# [Low Quantile ] Epoch 200/500 | Loss: 0.0063
# [Low Quantile ] Epoch 240/500 | Loss: 0.0061
# [Low Quantile ] Epoch 280/500 | Loss: 0.0061
# [Low Quantile ] Epoch 320/500 | Loss: 0.0060
# [Low Quantile ] Epoch 360/500 | Loss: 0.0064
# [Low Quantile ] Epoch 400/500 | Loss: 0.0059
# [Low Quantile ] Epoch 440/500 | Loss: 0.0058
# [Low Quantile ] Epoch 480/500 | Loss: 0.0056
# [High Quantile] Epoch 001/500 | Loss: 0.3673
# [High Quantile] Epoch 040/500 | Loss: 0.0082
# [High Quantile] Epoch 080/500 | Loss: 0.0059
# [High Quantile] Epoch 120/500 | Loss: 0.0054
# [High Quantile] Epoch 160/500 | Loss: 0.0053
# [High Quantile] Epoch 200/500 | Loss: 0.0050
# [High Quantile] Epoch 240/500 | Loss: 0.0052
# [High Quantile] Epoch 280/500 | Loss: 0.0051
# [High Quantile] Epoch 320/500 | Loss: 0.0049
# [High Quantile] Epoch 360/500 | Loss: 0.0047
# [High Quantile] Epoch 400/500 | Loss: 0.0051
# [High Quantile] Epoch 440/500 | Loss: 0.0050
# [High Quantile] Epoch 480/500 | Loss: 0.0047
#
# --- Training Base LSTM Model (Lookback: 120) ---
# [Low Quantile ] Epoch 001/500 | Loss: 0.2780
# [Low Quantile ] Epoch 040/500 | Loss: 0.0077
# [Low Quantile ] Epoch 080/500 | Loss: 0.0068
# [Low Quantile ] Epoch 120/500 | Loss: 0.0065
# [Low Quantile ] Epoch 160/500 | Loss: 0.0064
# [Low Quantile ] Epoch 200/500 | Loss: 0.0063
# [Low Quantile ] Epoch 240/500 | Loss: 0.0063
# [Low Quantile ] Epoch 280/500 | Loss: 0.0063
# [Low Quantile ] Epoch 320/500 | Loss: 0.0060
# [Low Quantile ] Epoch 360/500 | Loss: 0.0062
# [Low Quantile ] Epoch 400/500 | Loss: 0.0060
# [Low Quantile ] Epoch 440/500 | Loss: 0.0060
# [Low Quantile ] Epoch 480/500 | Loss: 0.0063
# [High Quantile] Epoch 001/500 | Loss: 0.4069
# [High Quantile] Epoch 040/500 | Loss: 0.0087
# [High Quantile] Epoch 080/500 | Loss: 0.0059
# [High Quantile] Epoch 120/500 | Loss: 0.0055
# [High Quantile] Epoch 160/500 | Loss: 0.0054
# [High Quantile] Epoch 200/500 | Loss: 0.0054
# [High Quantile] Epoch 240/500 | Loss: 0.0051
# [High Quantile] Epoch 280/500 | Loss: 0.0050
# [High Quantile] Epoch 320/500 | Loss: 0.0080
# [High Quantile] Epoch 360/500 | Loss: 0.0051
# [High Quantile] Epoch 400/500 | Loss: 0.0051
# [High Quantile] Epoch 440/500 | Loss: 0.0051
# [High Quantile] Epoch 480/500 | Loss: 0.0050
#
# --- Training Sentiment LSTM Model (Lookback: 120) ---
# [Low Quantile ] Epoch 001/500 | Loss: 0.2835
# [Low Quantile ] Epoch 040/500 | Loss: 0.0083
# [Low Quantile ] Epoch 080/500 | Loss: 0.0070
# [Low Quantile ] Epoch 120/500 | Loss: 0.0066
# [Low Quantile ] Epoch 160/500 | Loss: 0.0063
# [Low Quantile ] Epoch 200/500 | Loss: 0.0062
# [Low Quantile ] Epoch 240/500 | Loss: 0.0060
# [Low Quantile ] Epoch 280/500 | Loss: 0.0066
# [Low Quantile ] Epoch 320/500 | Loss: 0.0059
# [Low Quantile ] Epoch 360/500 | Loss: 0.0058
# [Low Quantile ] Epoch 400/500 | Loss: 0.0057
# [Low Quantile ] Epoch 440/500 | Loss: 0.0067
# [Low Quantile ] Epoch 480/500 | Loss: 0.0057
# [High Quantile] Epoch 001/500 | Loss: 0.5097
# [High Quantile] Epoch 040/500 | Loss: 0.0095
# [High Quantile] Epoch 080/500 | Loss: 0.0060
# [High Quantile] Epoch 120/500 | Loss: 0.0057
# [High Quantile] Epoch 160/500 | Loss: 0.0055
# [High Quantile] Epoch 200/500 | Loss: 0.0052
# [High Quantile] Epoch 240/500 | Loss: 0.0125
# [High Quantile] Epoch 280/500 | Loss: 0.0053
# [High Quantile] Epoch 320/500 | Loss: 0.0050
# [High Quantile] Epoch 360/500 | Loss: 0.0049
# [High Quantile] Epoch 400/500 | Loss: 0.0051
# [High Quantile] Epoch 440/500 | Loss: 0.0047
# [High Quantile] Epoch 480/500 | Loss: 0.0050
#
# --- Training Base LSTM Model (Lookback: 150) ---
# [Low Quantile ] Epoch 001/500 | Loss: 0.3145
# [Low Quantile ] Epoch 040/500 | Loss: 0.0093
# [Low Quantile ] Epoch 080/500 | Loss: 0.0069
# [Low Quantile ] Epoch 120/500 | Loss: 0.0066
# [Low Quantile ] Epoch 160/500 | Loss: 0.0065
# [Low Quantile ] Epoch 200/500 | Loss: 0.0063
# [Low Quantile ] Epoch 240/500 | Loss: 0.0063
# [Low Quantile ] Epoch 280/500 | Loss: 0.0062
# [Low Quantile ] Epoch 320/500 | Loss: 0.0062
# [Low Quantile ] Epoch 360/500 | Loss: 0.0062
# [Low Quantile ] Epoch 400/500 | Loss: 0.0058
# [Low Quantile ] Epoch 440/500 | Loss: 0.0060
# [Low Quantile ] Epoch 480/500 | Loss: 0.0059
# [High Quantile] Epoch 001/500 | Loss: 0.3077
# [High Quantile] Epoch 040/500 | Loss: 0.0078
# [High Quantile] Epoch 080/500 | Loss: 0.0057
# [High Quantile] Epoch 120/500 | Loss: 0.0056
# [High Quantile] Epoch 160/500 | Loss: 0.0054
# [High Quantile] Epoch 200/500 | Loss: 0.0077
# [High Quantile] Epoch 240/500 | Loss: 0.0052
# [High Quantile] Epoch 280/500 | Loss: 0.0054
# [High Quantile] Epoch 320/500 | Loss: 0.0050
# [High Quantile] Epoch 360/500 | Loss: 0.0053
# [High Quantile] Epoch 400/500 | Loss: 0.0050
# [High Quantile] Epoch 440/500 | Loss: 0.0050
# [High Quantile] Epoch 480/500 | Loss: 0.0053
#
# --- Training Sentiment LSTM Model (Lookback: 150) ---
# [Low Quantile ] Epoch 001/500 | Loss: 0.3126
# [Low Quantile ] Epoch 040/500 | Loss: 0.0087
# [Low Quantile ] Epoch 080/500 | Loss: 0.0069
# [Low Quantile ] Epoch 120/500 | Loss: 0.0068
# [Low Quantile ] Epoch 160/500 | Loss: 0.0064
# [Low Quantile ] Epoch 200/500 | Loss: 0.0063
# [Low Quantile ] Epoch 240/500 | Loss: 0.0060
# [Low Quantile ] Epoch 280/500 | Loss: 0.0060
# [Low Quantile ] Epoch 320/500 | Loss: 0.0059
# [Low Quantile ] Epoch 360/500 | Loss: 0.0063
# [Low Quantile ] Epoch 400/500 | Loss: 0.0054
# [Low Quantile ] Epoch 440/500 | Loss: 0.0058
# [Low Quantile ] Epoch 480/500 | Loss: 0.0059
# [High Quantile] Epoch 001/500 | Loss: 0.3892
# [High Quantile] Epoch 040/500 | Loss: 0.0087
# [High Quantile] Epoch 080/500 | Loss: 0.0061
# [High Quantile] Epoch 120/500 | Loss: 0.0058
# [High Quantile] Epoch 160/500 | Loss: 0.0057
# [High Quantile] Epoch 200/500 | Loss: 0.0051
# [High Quantile] Epoch 240/500 | Loss: 0.0059
# [High Quantile] Epoch 280/500 | Loss: 0.0049
# [High Quantile] Epoch 320/500 | Loss: 0.0056
# [High Quantile] Epoch 360/500 | Loss: 0.0054
# [High Quantile] Epoch 400/500 | Loss: 0.0048
# [High Quantile] Epoch 440/500 | Loss: 0.0047
# [High Quantile] Epoch 480/500 | Loss: 0.0050

# %%
# ============================================================
# 12. COMPARISON PRINTOUT
# ============================================================
print("\n" + "=" * 132)
print(f"{'FINAL COMPARISON (Base vs Sentiment - RNN)':^132}")
print("=" * 132)
print(
    f"{'Lookback':<9} | "
    f"{'Base Cov':<8} | {'Base Wdth':<9} | {'Base MAE':<9} | {'Base MSE':<9} | {'Base RMSE':<9} | {'Base PB-L':<10} | {'Base PB-H':<10} || "
    f"{'Sent Cov':<8} | {'Sent Wdth':<9} | {'Sent MAE':<9} | {'Sent MSE':<9} | {'Sent RMSE':<9} | {'Sent PB-L':<10} | {'Sent PB-H':<10}"
)
print("-" * 132)

for r in results:
    print(
        f"{r[0]:<9} | "
        f"{r[1]:<8.4f} | {r[2]:<9.4f} | {r[3]:<9.4f} | {r[4]:<9.4f} | {r[5]:<9.4f} | {r[6]:<10.4f} | {r[7]:<10.4f} || "
        f"{r[8]:<8.4f} | {r[9]:<9.4f} | {r[10]:<9.4f} | {r[11]:<9.4f} | {r[12]:<9.4f} | {r[13]:<10.4f} | {r[14]:<10.4f}"
    )

# Optional summary averages across lookbacks
base_avg = np.mean(np.array([[r[1], r[2], r[3], r[4], r[5], r[6], r[7]] for r in results]), axis=0)
sent_avg = np.mean(np.array([[r[8], r[9], r[10], r[11], r[12], r[13], r[14]] for r in results]), axis=0)

print("\n" + "=" * 90)
print(f"{'AVERAGE ACROSS LOOKBACKS':^90}")
print("=" * 90)
print(f"Base      -> Coverage: {base_avg[0]:.4f}, Width: {base_avg[1]:.4f}, MAE: {base_avg[2]:.4f}, MSE: {base_avg[3]:.4f}, RMSE: {base_avg[4]:.4f}, Pinball-L: {base_avg[5]:.4f}, Pinball-H: {base_avg[6]:.4f}")
print(f"Sentiment -> Coverage: {sent_avg[0]:.4f}, Width: {sent_avg[1]:.4f}, MAE: {sent_avg[2]:.4f}, MSE: {sent_avg[3]:.4f}, RMSE: {sent_avg[4]:.4f}, Pinball-L: {sent_avg[5]:.4f}, Pinball-H: {sent_avg[6]:.4f}")
# Out:
# ====================================================================================================================================
#                                              FINAL COMPARISON (Base vs Sentiment - RNN)
# ====================================================================================================================================
# Lookback  | Base Cov | Base Wdth | Base MAE  | Base MSE  | Base RMSE | Base PB-L  | Base PB-H  || Sent Cov | Sent Wdth | Sent MAE  | Sent MSE  | Sent RMSE | Sent PB-L  | Sent PB-H
# ------------------------------------------------------------------------------------------------------------------------------------
# 30        | 0.9074   | 6.8008    | 1.8476    | 5.3512    | 2.3133    | 0.1272     | 0.1013     || 0.9032   | 6.0110    | 1.5169    | 3.8599    | 1.9647    | 0.1082     | 0.1076
# 60        | 0.9439   | 7.4398    | 1.6442    | 4.3032    | 2.0744    | 0.1300     | 0.0883     || 0.9299   | 8.4126    | 2.2402    | 7.0755    | 2.6600    | 0.1598     | 0.0865
# 90        | 0.9411   | 7.8025    | 1.9176    | 5.7735    | 2.4028    | 0.1417     | 0.0877     || 0.9453   | 7.1812    | 1.7640    | 5.0178    | 2.2400    | 0.1313     | 0.0866
# 120       | 0.9271   | 6.9722    | 1.4656    | 3.5663    | 1.8885    | 0.1182     | 0.1063     || 0.9271   | 7.1150    | 1.7119    | 4.8189    | 2.1952    | 0.1287     | 0.0910
# 150       | 0.9383   | 6.6415    | 1.5243    | 3.7945    | 1.9479    | 0.1149     | 0.0874     || 0.9453   | 7.1093    | 1.6078    | 4.2979    | 2.0731    | 0.1249     | 0.0874
#
# ==========================================================================================
#                                  AVERAGE ACROSS LOOKBACKS
# ==========================================================================================
# Base      -> Coverage: 0.9316, Width: 7.1314, MAE: 1.6799, MSE: 4.5577, RMSE: 2.1254, Pinball-L: 0.1264, Pinball-H: 0.0942
# Sentiment -> Coverage: 0.9302, Width: 7.1658, MAE: 1.7682, MSE: 5.0140, RMSE: 2.2266, Pinball-L: 0.1306, Pinball-H: 0.0918

# %%
# ============================================================
# 13. PLOTS
# ============================================================

# Plot 1: Coverage vs Lookback
plt.figure(figsize=(10, 5))
plt.plot([r[0] for r in results], [r[1] for r in results], marker='o', label="Base (No Sent)")
plt.plot([r[0] for r in results], [r[8] for r in results], marker='o', label="With Sentiment")
plt.axhline(TARGET_COVERAGE, color='black', linestyle='--', label="Target Coverage")
plt.xlabel("Sequence Length (Lookback)")
plt.ylabel("Coverage")
plt.title("RNN: Coverage vs. Sequence Length")
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
# Plot 2: Width vs Lookback
plt.figure(figsize=(10, 5))
plt.plot([r[0] for r in results], [r[2] for r in results], marker='o', label="Base (No Sent)")
plt.plot([r[0] for r in results], [r[9] for r in results], marker='o', label="With Sentiment")
plt.xlabel("Sequence Length (Lookback)")
plt.ylabel("Average Interval Width")
plt.title("RNN: Uncertainty Width vs. Sequence Length")
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
# Plot 3 and 4: Forecast visualizations for each model and each lookback
for L in LOOKBACK_GRID:
    data = forecast_data[L]

    plt.figure(figsize=(12, 5))
    plt.plot(data["dates"], data["actual"], label="Actual Price", color='black', linewidth=1.5)
    plt.plot(data["dates"], data["base_mid"], label="Base Midpoint", color='blue', alpha=0.8)
    plt.fill_between(data["dates"], data["base_low"], data["base_high"], color='blue', alpha=0.2, label="95% Interval")
    plt.title(f"Base RNN Model Prediction (Lookback: {L})")
    plt.xlabel("Date")
    plt.ylabel("Price")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.gcf().autofmt_xdate()
    plt.show()

    plt.figure(figsize=(12, 5))
    plt.plot(data["dates"], data["actual"], label="Actual Price", color='black', linewidth=1.5)
    plt.plot(data["dates"], data["sent_mid"], label="Sent. Midpoint", color='green', alpha=0.8)
    plt.fill_between(data["dates"], data["sent_low"], data["sent_high"], color='green', alpha=0.2, label="95% Interval")
    plt.title(f"Sentiment RNN Model Prediction (Lookback: {L})")
    plt.xlabel("Date")
    plt.ylabel("Price")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.gcf().autofmt_xdate()
    plt.show()

# %%
# ============================================================
# 14. ERROR METRICS COMPARISON PLOTS
# ============================================================

lookbacks = [r[0] for r in results]

# Extract metrics
base_mae = [r[3] for r in results]
base_mse = [r[4] for r in results]
base_rmse = [r[5] for r in results]
base_pbl = [r[6] for r in results]
base_pbh = [r[7] for r in results]

sent_mae = [r[10] for r in results]
sent_mse = [r[11] for r in results]
sent_rmse = [r[12] for r in results]
sent_pbl = [r[13] for r in results]
sent_pbh = [r[14] for r in results]

# %%
# -----------------------------
# MAE Plot
# -----------------------------
plt.figure()
plt.plot(lookbacks, base_mae, marker='o', label="Base MAE")
plt.plot(lookbacks, sent_mae, marker='o', label="Sentiment MAE")
plt.title("RNN---MAE Comparison")
plt.xlabel("Lookback")
plt.ylabel("MAE")
plt.legend()
plt.grid()
plt.show()

# %%
# -----------------------------
# MSE Plot
# -----------------------------
plt.figure()
plt.plot(lookbacks, base_mse, marker='o', label="Base MSE")
plt.plot(lookbacks, sent_mse, marker='o', label="Sentiment MSE")
plt.title("RNN----MSE Comparison")
plt.xlabel("Lookback")
plt.ylabel("MSE")
plt.legend()
plt.grid()
plt.show()

# %%
# -----------------------------
# RMSE Plot
# -----------------------------
plt.figure()
plt.plot(lookbacks, base_rmse, marker='o', label="Base RMSE")
plt.plot(lookbacks, sent_rmse, marker='o', label="Sentiment RMSE")
plt.title("RNN---RMSE Comparison")
plt.xlabel("Lookback")
plt.ylabel("RMSE")
plt.legend()
plt.grid()
plt.show()

# %%
# -----------------------------
# Pinball Loss (Lower Quantile)
# -----------------------------
plt.figure()
plt.plot(lookbacks, base_pbl, marker='o', label="Base Pinball Low")
plt.plot(lookbacks, sent_pbl, marker='o', label="Sentiment Pinball Low")
plt.title(f"RNN---Pinball Loss Comparison (q={q_low})")
plt.xlabel("Lookback")
plt.ylabel("Pinball Loss")
plt.legend()
plt.grid()
plt.show()

# %%
# -----------------------------
# Pinball Loss (Upper Quantile)
# -----------------------------
plt.figure()
plt.plot(lookbacks, base_pbh, marker='o', label="Base Pinball High")
plt.plot(lookbacks, sent_pbh, marker='o', label="Sentiment Pinball High")
plt.title(f"RNN---Pinball Loss Comparison (q={q_high})")
plt.xlabel("Lookback")
plt.ylabel("Pinball Loss")
plt.legend()
plt.grid()
plt.show()
